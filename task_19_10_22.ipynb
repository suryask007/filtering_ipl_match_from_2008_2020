# %%
import pandas as ps
import matplotlib.pyplot as pt

# %%
df=ps.read_csv("IPL Matches 2008-2020.csv")

# %%
print(df)
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
#Checking null values and total values
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df.isnull()
# Out:
#         id   city   date  player_of_match  venue  neutral_venue  team1  team2  \
# 0    False  False  False            False  False          False  False  False
# 1    False  False  False            False  False          False  False  False
# 2    False  False  False            False  False          False  False  False
# 3    False  False  False            False  False          False  False  False
# 4    False  False  False            False  False          False  False  False
# ..     ...    ...    ...              ...    ...            ...    ...    ...
# 811  False  False  False            False  False          False  False  False
# 812  False  False  False            False  False          False  False  False
# 813  False  False  False            False  False          False  False  False
# 814  False  False  False            False  False          False  False  False
# 815  False  False  False            False  False          False  False  False
#
# ...

# %%
df.isnull().any()
# Out:
# id                 False
# city                True
# date               False
# player_of_match     True
# venue              False
# neutral_venue      False
# team1              False
# team2              False
# toss_winner        False
# toss_decision      False
# winner              True
# result              True
# result_margin       True
# eliminator          True
# method              True
# umpire1            False
# umpire2            False
# dtype: bool

# %%
df.to_string()
# Out:
# "          id            city        date    player_of_match                                                 venue  neutral_venue                        team1                        team2                  toss_winner toss_decision                       winner   result  result_margin eliminator method                umpire1          umpire2\n0     335982       Bangalore  2008-04-18        BB McCullum                                 M Chinnaswamy Stadium              0  Royal Challengers Bangalore        Kolkata Knight Riders  Royal Challengers Bangalore         field        Kolkata Knight Riders     runs          140.0          N    NaN              Asad Rauf      RE Koertzen\n1     335983      Chandigarh  2008-04-19         MEK Hussey            Punjab Cricket Association Stadium, Mohali              0              Kings XI Punjab          Chennai Super Kings          Chennai Super Kings           bat          Chennai Super Kings     runs           33.0          N    NaN             
# ...

# %%
#to display the first five values
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
#to find the row and columns
df.shape
# Out:
# (816, 17)

# %%
#display the information of the table
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
#to find the last five values
df.tail()
# Out:
#           id       city        date player_of_match  \
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %%
#drop the null values in particular row
df.dropna(subset="result_margin",inplace=True)
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 810  1216546       Dubai  2020-10-20        S Dhawan
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 799 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               799 non-null    int64
#  1   city             786 non-null    object
#  2   date             799 non-null    object
#  3   player_of_match  799 non-null    object
#  4   venue            799 non-null    object
#  5   neutral_venue    799 non-null    int64
#  6   team1            799 non-null    object
#  7   team2            799 non-null    object
#  8   toss_winner      799 non-null    object
#  9   toss_decision    799 non-null    object
#  10  winner           799 non-null    object
#  11  result           799 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       799 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          799 non-null    object
# ...

# %%
#duplicate cells 
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 810    False
# 812    False
# 813    False
# 814    False
# 815    False
# Length: 799, dtype: bool

# %%
#drop the duplicates values
df.drop_duplicates(inplace=True)
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 810  1216546       Dubai  2020-10-20        S Dhawan
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.corr()
# Out:
#                      id  neutral_venue  result_margin
# id             1.000000      -0.290921      -0.010501
# neutral_venue -0.290921       1.000000      -0.006445
# result_margin -0.010501      -0.006445       1.000000

# %%
df.plot()
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 810  1216546       Dubai  2020-10-20        S Dhawan
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.plot()
pt.show()

# %%
df["result_margin"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ds=ps.read_csv("IPL Matches 2008-2020.csv")
ds
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
mean=ds["result_margin"].mean()
ds["result_margin"].fillna(mean,inplace=True)
ds
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    816 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
#######2nd####

# %%
ef=ps.read_csv("IPL Ball-by-Ball 2008-2020.csv")
ef
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
ef.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193468 entries, 0 to 193467
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                193468 non-null  int64
#  1   inning            193468 non-null  int64
#  2   over              193468 non-null  int64
#  3   ball              193468 non-null  int64
#  4   batsman           193468 non-null  object
#  5   non_striker       193468 non-null  object
#  6   bowler            193468 non-null  object
#  7   batsman_runs      193468 non-null  int64
#  8   extra_runs        193468 non-null  int64
#  9   total_runs        193468 non-null  int64
#  10  non_boundary      193468 non-null  int64
#  11  is_wicket         193468 non-null  int64
#  12  dismissal_kind    9495 non-null    object
#  13  player_dismissed  9495 non-null    object
#  14  fielder           6784 non-null    object
#  15  extras_type       10233 non-null   object
# ...

# %%
ef.isnull().sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
ef.dropna(subset="fielder",inplace=True)
ef
# Out:
#              id  inning  over  ball     batsman   non_striker  \
# 32       335982       1    12     1  RT Ponting   BB McCullum
# 64       335982       1    17     1   DJ Hussey   BB McCullum
# 112      335982       1     5     2  SC Ganguly   BB McCullum
# 132      335982       2     7     5  MV Boucher      CL White
# 135      335982       2     8     2     B Akhil      CL White
# ...         ...     ...   ...   ...         ...           ...
# 193362  1237181       2    16     2   RG Sharma  Ishan Kishan
# 193375  1237181       2    18     3   HH Pandya  Ishan Kishan
# 193381  1237181       1    19     2    AR Patel       SS Iyer
# 193386  1237181       1     0     1  MP Stoinis      S Dhawan
# 193401  1237181       1     2     4   AM Rahane      S Dhawan
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 32            JH Kallis             0           0           0             0
# ...

# %%
ef.isnull().sum()
# Out:
# id                     0
# inning                 0
# over                   0
# ball                   0
# batsman                0
# non_striker            0
# bowler                 0
# batsman_runs           0
# extra_runs             0
# total_runs             0
# non_boundary           0
# is_wicket              0
# dismissal_kind         0
# player_dismissed       0
# fielder                0
# extras_type         6746
# batting_team           0
# bowling_team           7
# dtype: int64

# %%
ef.dropna(subset="extras_type",inplace=True)
ef
# Out:
#              id  inning  over  ball           batsman       non_striker  \
# 6666     336010       1     8     6         DJ Hussey           T Taibu
# 9098     336020       1    15     2         G Gambhir          S Dhawan
# 21653    392217       2    16     6         ML Hayden       S Badrinath
# 21871    392218       2    13     2  RE van der Merwe        MV Boucher
# 22752    392222       1    17     6            K Goel         PP Chawla
# 24210    392228       2    17     1         A Symonds         RG Sharma
# 29190    419114       2     8     5        KD Karthik       MF Maharoof
# 38616    419153       1     4     1         DJ Hussey         MK Tiwary
# 39969    419159       2     4     1           M Vijay          SK Raina
# 40669    419162       2     6     2      KP Pietersen          R Dravid
# 42356    501201       1    16     4          UT Yadav  RE van der Merwe
# 46432    501219       2    16     6         MK Tiwary          R Bhatia
# ...

# %%
ef.isnull().sum()
# Out:
# id                  0
# inning              0
# over                0
# ball                0
# batsman             0
# non_striker         0
# bowler              0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# non_boundary        0
# is_wicket           0
# dismissal_kind      0
# player_dismissed    0
# fielder             0
# extras_type         0
# batting_team        0
# bowling_team        1
# dtype: int64

# %%
ef.dropna(subset="bowling_team",inplace=True)
ef
# Out:
#              id  inning  over  ball           batsman       non_striker  \
# 6666     336010       1     8     6         DJ Hussey           T Taibu
# 9098     336020       1    15     2         G Gambhir          S Dhawan
# 21653    392217       2    16     6         ML Hayden       S Badrinath
# 21871    392218       2    13     2  RE van der Merwe        MV Boucher
# 22752    392222       1    17     6            K Goel         PP Chawla
# 24210    392228       2    17     1         A Symonds         RG Sharma
# 29190    419114       2     8     5        KD Karthik       MF Maharoof
# 38616    419153       1     4     1         DJ Hussey         MK Tiwary
# 39969    419159       2     4     1           M Vijay          SK Raina
# 40669    419162       2     6     2      KP Pietersen          R Dravid
# 42356    501201       1    16     4          UT Yadav  RE van der Merwe
# 46432    501219       2    16     6         MK Tiwary          R Bhatia
# ...

# %%
ef.plot()
# Out:
# <AxesSubplot:>

# %%
ef.plot(kind="scatter",x="ball",y="batsman_runs")
# Out:
# <AxesSubplot:xlabel='ball', ylabel='batsman_runs'>
